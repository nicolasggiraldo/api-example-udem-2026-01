# %%
import pickle
import pandas as pd
import seaborn as sns 
import numpy as np

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error

# %%
input_dataset = 'housing.csv'
output_file = '../model.pickle'

# %%
# Load dataset
df = pd.read_csv(input_dataset).drop(columns='rownames')
df.head()
# Out:
#    price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase gashw  \
# 0  42000     5850         3        1        2      yes      no      yes    no
# 1  38500     4000         2        1        1      yes      no       no    no
# 2  49500     3060         3        1        1      yes      no       no    no
# 3  60500     6650         3        1        2      yes     yes       no    no
# 4  61000     6360         2        1        1      yes      no       no    no
#
#   airco  garagepl prefarea
# 0    no         1       no
# 1    no         0       no
# 2    no         0       no
# 3    no         0       no
# 4    no         0       no

# %%
sns.pairplot(df)

# %%
# Extract features and target variable
X = df[['lotsize', 'bedrooms']].values
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# Train linear regression model
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = regr.predict(X_train)
y_pred_test = regr.predict(X_test)

train_rmse = root_mean_squared_error(y_train, y_pred_train)
test_rmse = root_mean_squared_error(y_test, y_pred_test)

train_mape = round(mean_absolute_percentage_error(y_train, y_pred_train), 2)
test_mape = round(mean_absolute_percentage_error(y_test, y_pred_test), 2)

mean_absolute_percentage_error

#print(f'Train RMSE: {train_rmse}')
#print(f'Test RMSE: {test_rmse}')

print(f'Train MAPE: {train_mape}')
print(f'Test MAPE: {test_mape}')
# Out:
# Train MAPE: 0.24
# Test MAPE: 0.27

# %%
X_test[:10]
# Out:
# array([[5000,    3],
#        [3180,    4],
#        [6600,    4],
#        [6060,    3],
#        [5985,    3],
#        [3960,    3],
#        [5400,    4],
#        [3450,    3],
#        [6000,    4],
#        [5880,    2]])

# %%
regr.predict([[5000, 3]])[0]
# Out:
# np.float64(67574.63889875865)

# %%
# Store data (serialize)
with open(output_file, 'wb') as file:
    pickle.dump(regr, file)

# %%
# Load data (deserialize)
with open(output_file, 'rb') as file:
    model = pickle.load(file)

# %%
regr
# Out:
# LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
test_mape, round(mean_absolute_percentage_error(y_test, model.predict(X_test)), 2)
# Out:
# (0.27, 0.27)

# %%
test_mape == round(mean_absolute_percentage_error(y_test, model.predict(X_test)), 2)
# Out:
# True
